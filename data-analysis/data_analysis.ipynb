# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import statsmodels.api as sm # 导入 statsmodels 用于 Q-Q 图
import itertools # 用于帮助迭代
from scipy.stats import shapiro

# %%
# Read the CSV file
df = pd.read_csv("run_table.csv")
benchmark_list=df['benchmark'].unique().tolist()
phase_list = ['cold','warm']
compilations_list = ['original', 'cython', 'numba']
x_list = ['cold_start_energy','warm_start_energy', 'cold_start_cpu_util', 'warm_start_cpu_util',
        'cold_start_duration', 'warm_start_duration', 'cold_start_memory_util','warm_start_memory_util']

# %%
# create statistic table
grouped = df.groupby(['benchmark', 'compilation'])

# mean,std,min,max
stats = grouped.describe()

print(stats)
stats.to_csv("grouped_stats.csv")
# Out:
#                                                     cold_start_energy  \
#                                                                 count
# benchmark                               compilation
# binary_trees/original.py                cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# dac_mergesort/original.py               cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# dijkstra/original.py                    cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# fannkuch/original.py                    cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# insertionsort/original.py               cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# mandlebrot/original.py                  cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# nbody/original.py                       cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# recur_matrix_multiplication/original.py cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# richards/original.py                    cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# spectral_norm/original.py               cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
#
#                                                                           \
#                                                           mean       std
# benchmark                               compilation
# binary_trees/original.py                cython        2.917000  0.349321
#                                         numba         4.118667  0.240021
#                                         original      4.006000  0.347299
# dac_mergesort/original.py               cython        1.620067  0.225760
#                                         numba         2.178133  0.206140
#                                         original      2.156800  0.220458
# dijkstra/original.py                    cython        2.231733  0.198260
#                                         numba         2.621667  0.187315
#                                         original      2.675600  0.335882
# fannkuch/original.py                    cython        1.417600  0.204104
#                                         numba         1.715667  0.251831
#                                         original      1.788600  0.188161
# insertionsort/original.py               cython        1.893867  0.179035
#                                         numba         1.802333  0.145599
#                                         original      1.765733  0.205873
# mandlebrot/original.py                  cython       19.742667  0.612540
#                                         numba        27.896800  0.688270
#                                         original     27.564800  0.751849
# nbody/original.py                       cython        4.906200  0.270173
#                                         numba         4.473000  0.370875
#                                         original      4.399333  0.299241
# recur_matrix_multiplication/original.py cython        1.408733  0.160121
#                                         numba         3.199200  0.340937
#                                         original      3.368933  0.211632
# richards/original.py                    cython        6.075533  0.239202
#                                         numba         4.538200  0.298660
#                                         original      4.635200  0.236809
# spectral_norm/original.py               cython        8.752933  0.252055
#                                         numba        10.184133  0.305028
#                                         original     10.037800  0.332796
#
#                                                                               \
#                                                         min      25%     50%
# benchmark                               compilation
# binary_trees/original.py                cython        2.305   2.7590   2.970
#                                         numba         3.664   3.9715   4.122
#                                         original      3.366   3.8355   3.981
# dac_mergesort/original.py               cython        1.082   1.5085   1.629
#                                         numba         1.812   2.0280   2.217
#                                         original      1.635   2.0270   2.251
# dijkstra/original.py                    cython        1.740   2.1555   2.263
#                                         numba         2.205   2.5450   2.647
#                                         original      2.098   2.4840   2.749
# fannkuch/original.py                    cython        1.057   1.2485   1.409
#                                         numba         1.255   1.5125   1.766
#                                         original      1.431   1.6395   1.846
# insertionsort/original.py               cython        1.555   1.7320   1.924
#                                         numba         1.559   1.6785   1.858
#                                         original      1.446   1.5950   1.793
# mandlebrot/original.py                  cython       18.470  19.2905  19.853
#                                         numba        26.678  27.3290  28.082
#                                         original     26.127  27.0295  27.581
# nbody/original.py                       cython        4.318   4.8445   4.947
#                                         numba         3.623   4.3025   4.436
#                                         original      3.832   4.1985   4.430
# recur_matrix_multiplication/original.py cython        1.170   1.2810   1.360
#                                         numba         2.351   3.0210   3.184
#                                         original      3.011   3.2420   3.343
# richards/original.py                    cython        5.693   5.8700   6.043
#                                         numba         3.985   4.4220   4.582
#                                         original      4.158   4.4715   4.667
# spectral_norm/original.py               cython        8.153   8.6315   8.729
#                                         numba         9.612   9.9785  10.269
#                                         original      9.089   9.9515  10.109
#
#                                                                       \
#                                                          75%     max
# benchmark                               compilation
# binary_trees/original.py                cython        3.0845   3.584
#                                         numba         4.3045   4.492
#                                         original      4.2185   4.577
# dac_mergesort/original.py               cython        1.7820   1.987
#                                         numba         2.3485   2.432
#                                         original      2.2975   2.417
# dijkstra/original.py                    cython        2.3410   2.615
#                                         numba         2.7440   2.864
#                                         original      2.8625   3.270
# fannkuch/original.py                    cython        1.6225   1.706
#                                         numba         1.9420   2.011
#                                         original      1.9465   1.995
# insertionsort/original.py               cython        2.0475   2.096
#                                         numba         1.8925   2.029
#                                         original      1.9305   2.042
# mandlebrot/original.py                  cython       20.1545  20.730
#                                         numba        28.4260  28.716
#                                         original     28.1360  28.538
# nbody/original.py                       cython        5.0210   5.459
#                                         numba         4.6845   5.061
#                                         original      4.5865   4.896
# recur_matrix_multiplication/original.py cython        1.5345   1.741
#                                         numba         3.3800   3.734
#                                         original      3.5435   3.678
# richards/original.py                    cython        6.2725   6.464
#                                         numba         4.6870   5.103
#                                         original      4.8085   5.005
# spectral_norm/original.py               cython        8.9395   9.124
#                                         numba        10.3960  10.664
#                                         original     10.2370  10.389
#
#                                                     warm_start_energy  \
#                                                                 count
# benchmark                               compilation
# binary_trees/original.py                cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# dac_mergesort/original.py               cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# dijkstra/original.py                    cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# fannkuch/original.py                    cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# insertionsort/original.py               cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# mandlebrot/original.py                  cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# nbody/original.py                       cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# recur_matrix_multiplication/original.py cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# richards/original.py                    cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
# spectral_norm/original.py               cython                   15.0
#                                         numba                    15.0
#                                         original                 15.0
#
#                                                                 ...  \
#                                                           mean  ...
# benchmark                               compilation             ...
# binary_trees/original.py                cython        2.616267  ...
#                                         numba         4.169067  ...
#                                         original      3.893467  ...
# dac_mergesort/original.py               cython        1.640333  ...
#                                         numba         1.939067  ...
#                                         original      1.893467  ...
# dijkstra/original.py                    cython        2.288067  ...
#                                         numba         2.654133  ...
#                                         original      2.721800  ...
# fannkuch/original.py                    cython        0.973267  ...
#                                         numba         1.337067  ...
#                                         original      1.272267  ...
# insertionsort/original.py               cython        1.828000  ...
#                                         numba         1.774333  ...
#                                         original      1.784933  ...
# mandlebrot/original.py                  cython       19.838733  ...
#                                         numba        27.652400  ...
#                                         original     27.137267  ...
# nbody/original.py                       cython        5.058133  ...
#                                         numba         4.780667  ...
#                                         original      4.600200  ...
# recur_matrix_multiplication/original.py cython        1.602067  ...
#                                         numba         3.280200  ...
#                                         original      3.271867  ...
# richards/original.py                    cython        5.484600  ...
#                                         numba         4.019267  ...
#                                         original      3.929800  ...
# spectral_norm/original.py               cython        8.595800  ...
#                                         numba        10.030667  ...
#                                         original     10.051133  ...
#
#                                                     cold_start_memory_util  \
#                                                                        75%
# benchmark                               compilation
# binary_trees/original.py                cython                 444528640.0
#                                         numba                  449005568.0
#                                         original               451213312.0
# dac_mergesort/original.py               cython                  31039488.0
#                                         numba                   30914560.0
#                                         original                30920704.0
# dijkstra/original.py                    cython                  10995712.0
#                                         numba                   10485760.0
#                                         original                10452992.0
# fannkuch/original.py                    cython                  25661440.0
#                                         numba                   25376768.0
#                                         original                25309184.0
# insertionsort/original.py               cython                  16893952.0
#                                         numba                   16629760.0
#                                         original                16607232.0
# mandlebrot/original.py                  cython                 377477120.0
#                                         numba                  393304064.0
#                                         original               395272192.0
# nbody/original.py                       cython                  10670080.0
#                                         numba                   10192896.0
#                                         original                10240000.0
# recur_matrix_multiplication/original.py cython                  38842368.0
#                                         numba                   10080256.0
#                                         original                10074112.0
# richards/original.py                    cython                  25704448.0
#                                         numba                   26040320.0
#                                         original                26028032.0
# spectral_norm/original.py               cython                  80226304.0
#                                         numba                   78331904.0
#                                         original                78354432.0
#
#                                                                   \
#                                                              max
# benchmark                               compilation
# binary_trees/original.py                cython       448466944.0
#                                         numba        455565312.0
#                                         original     452894720.0
# dac_mergesort/original.py               cython        31174656.0
#                                         numba         30969856.0
#                                         original      30961664.0
# dijkstra/original.py                    cython        11034624.0
#                                         numba         10493952.0
#                                         original      10526720.0
# fannkuch/original.py                    cython        25751552.0
#                                         numba         25452544.0
#                                         original      25452544.0
# insertionsort/original.py               cython        16998400.0
#                                         numba         16740352.0
#                                         original      16642048.0
# mandlebrot/original.py                  cython       384024576.0
#                                         numba        396062720.0
#                                         original     398532608.0
# nbody/original.py                       cython        10727424.0
#                                         numba         10280960.0
#                                         original      10313728.0
# recur_matrix_multiplication/original.py cython        38952960.0
#                                         numba         10117120.0
#                                         original      10117120.0
# richards/original.py                    cython        25837568.0
#                                         numba         26132480.0
#                                         original      26112000.0
# spectral_norm/original.py               cython        80961536.0
#                                         numba         78647296.0
#                                         original      78950400.0
#
#                                                     warm_start_memory_util  \
#                                                                      count
# benchmark                               compilation
# binary_trees/original.py                cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
# dac_mergesort/original.py               cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
# dijkstra/original.py                    cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
# fannkuch/original.py                    cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
# insertionsort/original.py               cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
# mandlebrot/original.py                  cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
# nbody/original.py                       cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
# recur_matrix_multiplication/original.py cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
# richards/original.py                    cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
# spectral_norm/original.py               cython                        15.0
#                                         numba                         15.0
#                                         original                      15.0
#
#                                                                    \
#                                                              mean
# benchmark                               compilation
# binary_trees/original.py                cython       4.755464e+08
#                                         numba        4.811426e+08
#                                         original     4.818196e+08
# dac_mergesort/original.py               cython       3.088821e+07
#                                         numba        3.077379e+07
#                                         original     3.076233e+07
# dijkstra/original.py                    cython       1.092949e+07
#                                         numba        1.055321e+07
#                                         original     1.063840e+07
# fannkuch/original.py                    cython       2.553091e+07
#                                         numba        2.525867e+07
#                                         original     2.520105e+07
# insertionsort/original.py               cython       1.687252e+07
#                                         numba        1.658853e+07
#                                         original     1.654484e+07
# mandlebrot/original.py                  cython       3.813163e+08
#                                         numba        3.951179e+08
#                                         original     3.964958e+08
# nbody/original.py                       cython       1.058707e+07
#                                         numba        1.017446e+07
#                                         original     1.023700e+07
# recur_matrix_multiplication/original.py cython       3.896771e+07
#                                         numba        1.019412e+07
#                                         original     1.020232e+07
# richards/original.py                    cython       2.552409e+07
#                                         numba        2.582774e+07
#                                         original     2.578924e+07
# spectral_norm/original.py               cython       8.006424e+07
#                                         numba        7.800777e+07
#                                         original     7.795507e+07
#
#                                                                    \
#                                                               std
# benchmark                               compilation
# binary_trees/original.py                cython       5.306918e+06
#                                         numba        2.137576e+06
#                                         original     3.933459e+06
# dac_mergesort/original.py               cython       7.455984e+04
#                                         numba        9.438423e+04
#                                         original     7.407933e+04
# dijkstra/original.py                    cython       7.493180e+04
#                                         numba        8.024796e+04
#                                         original     8.758255e+04
# fannkuch/original.py                    cython       3.931388e+04
#                                         numba        8.847017e+04
#                                         original     7.043283e+04
# insertionsort/original.py               cython       6.830216e+04
#                                         numba        9.482252e+04
#                                         original     7.352400e+04
# mandlebrot/original.py                  cython       2.631270e+06
#                                         numba        2.656895e+06
#                                         original     2.714558e+06
# nbody/original.py                       cython       1.100648e+05
#                                         numba        7.116405e+04
#                                         original     1.174291e+05
# recur_matrix_multiplication/original.py cython       5.683602e+04
#                                         numba        8.752415e+04
#                                         original     1.039471e+05
# richards/original.py                    cython       1.084569e+05
#                                         numba        1.061330e+05
#                                         original     9.564965e+04
# spectral_norm/original.py               cython       4.188504e+05
#                                         numba        5.275734e+05
#                                         original     5.873033e+05
#
#                                                                                \
#                                                              min          25%
# benchmark                               compilation
# binary_trees/original.py                cython       463278080.0  471928832.0
#                                         numba        478011392.0  480065536.0
#                                         original     477966336.0  479031296.0
# dac_mergesort/original.py               cython        30810112.0   30812160.0
#                                         numba         30621696.0   30701568.0
#                                         original      30613504.0   30713856.0
# dijkstra/original.py                    cython        10833920.0   10864640.0
#                                         numba         10469376.0   10491904.0
#                                         original      10493952.0   10579968.0
# fannkuch/original.py                    cython        25473024.0   25505792.0
#                                         numba         25104384.0   25231360.0
#                                         original      25100288.0   25133056.0
# insertionsort/original.py               cython        16793600.0   16812032.0
#                                         numba         16461824.0   16498688.0
#                                         original      16392192.0   16498688.0
# mandlebrot/original.py                  cython       378126336.0  378783744.0
#                                         numba        392511488.0  393459712.0
#                                         original     394035200.0  394500096.0
# nbody/original.py                       cython        10416128.0   10491904.0
#                                         numba         10063872.0   10113024.0
#                                         original      10067968.0   10145792.0
# recur_matrix_multiplication/original.py cython        38830080.0   38942720.0
#                                         numba         10072064.0   10129408.0
#                                         original      10063872.0   10119168.0
# richards/original.py                    cython        25378816.0   25423872.0
#                                         numba         25657344.0   25741312.0
#                                         original      25657344.0   25712640.0
# spectral_norm/original.py               cython        79392768.0   79837184.0
#                                         numba         76746752.0   77920256.0
#                                         original      76644352.0   77733888.0
#
#                                                                                \
#                                                              50%          75%
# benchmark                               compilation
# binary_trees/original.py                cython       477298688.0  477956096.0
#                                         numba        480632832.0  482371584.0
#                                         original     480092160.0  483747840.0
# dac_mergesort/original.py               cython        30887936.0   30920704.0
#                                         numba         30781440.0   30838784.0
#                                         original      30789632.0   30828544.0
# dijkstra/original.py                    cython        10924032.0   10995712.0
#                                         numba         10493952.0   10604544.0
#                                         original      10649600.0   10702848.0
# fannkuch/original.py                    cython        25530368.0   25554944.0
#                                         numba         25276416.0   25290752.0
#                                         original      25219072.0   25266176.0
# insertionsort/original.py               cython        16871424.0   16893952.0
#                                         numba         16625664.0   16658432.0
#                                         original      16539648.0   16607232.0
# mandlebrot/original.py                  cython       381878272.0  382586880.0
#                                         numba        394047488.0  397082624.0
#                                         original     394539008.0  397926400.0
# nbody/original.py                       cython        10579968.0   10670080.0
#                                         numba         10186752.0   10215424.0
#                                         original      10240000.0   10313728.0
# recur_matrix_multiplication/original.py cython        38973440.0   39008256.0
#                                         numba         10190848.0   10254336.0
#                                         original      10199040.0   10264576.0
# richards/original.py                    cython        25509888.0   25595904.0
#                                         numba         25853952.0   25882624.0
#                                         original      25792512.0   25839616.0
# spectral_norm/original.py               cython        79986688.0   80226304.0
#                                         numba         78106624.0   78331904.0
#                                         original      77963264.0   78354432.0
#
#
#                                                              max
# benchmark                               compilation
# binary_trees/original.py                cython       483356672.0
#                                         numba        485855232.0
#                                         original     488738816.0
# dac_mergesort/original.py               cython        31043584.0
#                                         numba         30912512.0
#                                         original      30859264.0
# dijkstra/original.py                    cython        11034624.0
#                                         numba         10706944.0
#                                         original      10747904.0
# fannkuch/original.py                    cython        25608192.0
#                                         numba         25444352.0
#                                         original      25313280.0
# insertionsort/original.py               cython        16998400.0
#                                         numba         16740352.0
#                                         original      16642048.0
# mandlebrot/original.py                  cython       386080768.0
#                                         numba        401870848.0
#                                         original     401915904.0
# nbody/original.py                       cython        10727424.0
#                                         numba         10297344.0
#                                         original      10424320.0
# recur_matrix_multiplication/original.py cython        39051264.0
#                                         numba         10313728.0
#                                         original      10424320.0
# richards/original.py                    cython        25702400.0
#                                         numba         25997312.0
#                                         original      25993216.0
# spectral_norm/original.py               cython        80961536.0
#                                         numba         78647296.0
#                                         original      78950400.0
#
# [30 rows x 64 columns]

# %%
def box_plot(benchmark_to_plot, phase, df):
    # create plot image name
    benchmark_name = benchmark_to_plot.split('.')[0]
    benchmark_name = benchmark_name.replace('/', '_')

    df_filtered = df[df['benchmark'] == benchmark_to_plot]

    # 2*2 grid
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Energy
    sns.boxplot(data=df_filtered, x='compilation', y=f'{phase}_start_energy', ax=axes[0, 0])
    axes[0, 0].set_title(f'{phase} start energy')
    axes[0, 0].set_ylabel('Energy (J)')
    axes[0, 0].set_xlabel('') # remove xlabel

    # CPU Utilization
    sns.boxplot(data=df_filtered, x='compilation', y=f'{phase}_start_cpu_util', ax=axes[0, 1])
    axes[0, 1].set_title(f'{phase} start CPU utilization')
    axes[0, 1].set_ylabel('CPU Utilization (%)')
    axes[0, 1].set_xlabel('')

    # Duration
    sns.boxplot(data=df_filtered, x='compilation', y=f'{phase}_start_duration', ax=axes[1, 0])
    axes[1, 0].set_title(f'{phase} start duration')
    axes[1, 0].set_ylabel('Duration (s)')
    axes[1, 0].set_xlabel('Compilation Tool') # add x label at bottom

    # Memory Utilization
    sns.boxplot(data=df_filtered, x='compilation', y=f'{phase}_start_memory_util', ax=axes[1, 1])
    axes[1, 1].set_title(f'{phase} start memory utilization')
    axes[1, 1].set_ylabel('Memory (bytes)')
    axes[1, 1].set_xlabel('Compilation Tool')

    fig.suptitle(f'{phase} start metrics for {benchmark_to_plot}', fontsize=16)
    plt.tight_layout()
    plt.savefig(f'plots/box_{phase}_{benchmark_name}.png')
    plt.show()
    plt.close(fig)

# %%
def density_plot(benchmark_to_plot, phase, df):
    # create plot image name
    benchmark_name = benchmark_to_plot.split('.')[0]
    benchmark_name = benchmark_name.replace('/', '_')

    df_filtered = df[df['benchmark'] == benchmark_to_plot]

    # 2*2 grid
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    # density plot, fill=True, alpha=0.3, more readable
    sns.kdeplot(data=df_filtered,x=f'{phase}_start_energy',hue='compilation',
        fill=True,alpha=0.3,ax=axes[0, 0])
    axes[0, 0].set_title(f'{phase} start energy')
    axes[0, 0].set_ylabel('Density')
    axes[0, 0].set_xlabel('Energy(J)')

    sns.kdeplot(data=df_filtered,x=f'{phase}_start_cpu_util',hue='compilation',
        fill=True,alpha=0.3,ax=axes[0, 1])
    axes[0, 1].set_title(f'{phase} start CPU utilization')
    axes[0, 1].set_ylabel('Density')
    axes[0, 1].set_xlabel('CPU Utilization(%)')

    sns.kdeplot(data=df_filtered,x=f'{phase}_start_duration',hue='compilation',
        fill=True,alpha=0.3,ax=axes[1, 0])
    axes[1, 0].set_title(f'{phase} start duration')
    axes[1, 0].set_ylabel('Density')
    axes[1, 0].set_xlabel('Duration')

    sns.kdeplot(data=df_filtered,x=f'{phase}_start_memory_util',hue='compilation',
        fill=True,alpha=0.3,ax=axes[1, 1])
    axes[1, 1].set_title(f'{phase} start memory utilization')
    axes[1, 1].set_ylabel('Density')
    axes[1, 1].set_xlabel('Memory Utilization(bytes)')

    fig.suptitle(f'{phase} start metrics density for {benchmark_to_plot}', fontsize=16)
    plt.tight_layout()
    plt.savefig(f'plots/density_{phase}_{benchmark_name}.png')
    plt.show()
    plt.close(fig)

# %%
# box plot and density plot
for benchmark_to_plot in benchmark_list:
    for phase in phase_list:
        box_plot(benchmark_to_plot, phase, df)
        density_plot(benchmark_to_plot, phase, df)

# %%
# qq plot
for metric in x_list:

    print(f"qq plot for {metric} ...")

    # 6x5 grid
    fig, axes = plt.subplots(6, 5, figsize=(20, 24))

    axes_flat = axes.flatten()

    # 30 combine
    combinations = list(itertools.product(benchmark_list, compilations_list))

    for i, (bench, comp) in enumerate(combinations):
        ax = axes_flat[i]

        data_to_plot = df[
            (df['benchmark'] == bench) &
            (df['compilation'] == comp)
        ][metric]

        # Q-Q plot
        if not data_to_plot.empty:
            sm.qqplot(data_to_plot, line='s', ax=ax)

        benchmark_name = bench.split('.')[0]
        benchmark_name = benchmark_name.replace('/', '_')
        ax.set_title(f'{benchmark_name} | {comp}', fontsize=9)

        ax.set_xlabel('')
        ax.set_ylabel('')

    # title
    fig.suptitle(f'Q-Q Plots for Normality Check: {metric}', fontsize=24)
    plt.tight_layout()

    output_filename = f'plots/qq_plots_{metric}.png'
    plt.savefig(output_filename)
    print(f"saved: {output_filename}")

    plt.close(fig)

print("\nfinished")
# Out:
# qq plot for cold_start_energy ...
# saved: plots/qq_plots_cold_start_energy.png
# qq plot for warm_start_energy ...
# saved: plots/qq_plots_warm_start_energy.png
# qq plot for cold_start_cpu_util ...
# saved: plots/qq_plots_cold_start_cpu_util.png
# qq plot for warm_start_cpu_util ...
# saved: plots/qq_plots_warm_start_cpu_util.png
# qq plot for cold_start_duration ...
# saved: plots/qq_plots_cold_start_duration.png
# qq plot for warm_start_duration ...
# saved: plots/qq_plots_warm_start_duration.png
# qq plot for cold_start_memory_util ...
# saved: plots/qq_plots_cold_start_memory_util.png
# qq plot for warm_start_memory_util ...
# saved: plots/qq_plots_warm_start_memory_util.png
#
# finished

# %%
# Shapiro-Wilk TEST
alpha = 0.05
results_list = []
for metric in x_list:
    for bench in benchmark_list:
        for comp in compilations_list:
            data_to_test = df[
                (df['benchmark'] == bench) &
                (df['compilation'] == comp)
            ][metric]
            # at least 3 data for test
            if len(data_to_test) >= 3:
                stat, p_value = shapiro(data_to_test)
                # if p-value < 0.05, we conclude the data is not normally distributed
                is_normal = p_value > alpha

            else:
                stat, p_value, is_normal = np.nan, np.nan, False # not enough data

            results_list.append({
                'metric': metric,
                'benchmark': bench,
                'compilation': comp,
                'statistic': stat,
                'p_value': p_value,
                f'is_normal (p > {alpha})': is_normal
            })

SW_df = pd.DataFrame(results_list)

print("Shapiro-Wilk test result")
print(SW_df)

print("\n--- Subsets judged to be non-normally distributed ---")
print(SW_df[SW_df[f'is_normal (p > {alpha})'] == False])
# Out:
# Shapiro-Wilk test result
#                      metric                  benchmark compilation  statistic  \
# 0         cold_start_energy   binary_trees/original.py    original   0.978368
# 1         cold_start_energy   binary_trees/original.py      cython   0.951322
# 2         cold_start_energy   binary_trees/original.py       numba   0.964537
# 3         cold_start_energy  dac_mergesort/original.py    original   0.871211
# 4         cold_start_energy  dac_mergesort/original.py      cython   0.951367
# ..                      ...                        ...         ...        ...
# 235  warm_start_memory_util       richards/original.py      cython   0.934964
# 236  warm_start_memory_util       richards/original.py       numba   0.918450
# 237  warm_start_memory_util  spectral_norm/original.py    original   0.959344
# 238  warm_start_memory_util  spectral_norm/original.py      cython   0.969639
# 239  warm_start_memory_util  spectral_norm/original.py       numba   0.895398
#
#       p_value  is_normal (p > 0.05)
# 0    0.957137                  True
# 1    0.545511                  True
# 2    0.770582                  True
# 3    0.035152                 False
# 4    0.546237                  True
# ..        ...                   ...
# 235  0.323236                  True
# 236  0.182418                  True
# 237  0.680994                  True
# 238  0.852670                  True
# 239  0.080976                  True
#
# [240 rows x 6 columns]
#
# --- Subsets judged to be non-normally distributed ---
#                      metric                                benchmark  \
# 3         cold_start_energy                dac_mergesort/original.py
# 27        cold_start_energy                spectral_norm/original.py
# 38        warm_start_energy                     dijkstra/original.py
# 42        warm_start_energy                insertionsort/original.py
# 44        warm_start_energy                insertionsort/original.py
# 64      cold_start_cpu_util                dac_mergesort/original.py
# 90      warm_start_cpu_util                 binary_trees/original.py
# 91      warm_start_cpu_util                 binary_trees/original.py
# 92      warm_start_cpu_util                 binary_trees/original.py
# 93      warm_start_cpu_util                dac_mergesort/original.py
# 94      warm_start_cpu_util                dac_mergesort/original.py
# 95      warm_start_cpu_util                dac_mergesort/original.py
# 96      warm_start_cpu_util                     dijkstra/original.py
# 97      warm_start_cpu_util                     dijkstra/original.py
# 98      warm_start_cpu_util                     dijkstra/original.py
# 99      warm_start_cpu_util                     fannkuch/original.py
# 100     warm_start_cpu_util                     fannkuch/original.py
# 102     warm_start_cpu_util                insertionsort/original.py
# 103     warm_start_cpu_util                insertionsort/original.py
# 104     warm_start_cpu_util                insertionsort/original.py
# 106     warm_start_cpu_util                   mandlebrot/original.py
# 108     warm_start_cpu_util                        nbody/original.py
# 110     warm_start_cpu_util                        nbody/original.py
# 111     warm_start_cpu_util  recur_matrix_multiplication/original.py
# 112     warm_start_cpu_util  recur_matrix_multiplication/original.py
# 113     warm_start_cpu_util  recur_matrix_multiplication/original.py
# 114     warm_start_cpu_util                     richards/original.py
# 117     warm_start_cpu_util                spectral_norm/original.py
# 119     warm_start_cpu_util                spectral_norm/original.py
# 123     cold_start_duration                dac_mergesort/original.py
# 124     cold_start_duration                dac_mergesort/original.py
# 126     cold_start_duration                     dijkstra/original.py
# 128     cold_start_duration                     dijkstra/original.py
# 129     cold_start_duration                     fannkuch/original.py
# 132     cold_start_duration                insertionsort/original.py
# 133     cold_start_duration                insertionsort/original.py
# 134     cold_start_duration                insertionsort/original.py
# 138     cold_start_duration                        nbody/original.py
# 139     cold_start_duration                        nbody/original.py
# 140     cold_start_duration                        nbody/original.py
# 147     cold_start_duration                spectral_norm/original.py
# 157     warm_start_duration                     dijkstra/original.py
# 159     warm_start_duration                     fannkuch/original.py
# 160     warm_start_duration                     fannkuch/original.py
# 161     warm_start_duration                     fannkuch/original.py
# 162     warm_start_duration                insertionsort/original.py
# 164     warm_start_duration                insertionsort/original.py
# 166     warm_start_duration                   mandlebrot/original.py
# 170     warm_start_duration                        nbody/original.py
# 172     warm_start_duration  recur_matrix_multiplication/original.py
# 178     warm_start_duration                spectral_norm/original.py
# 180  cold_start_memory_util                 binary_trees/original.py
# 188  cold_start_memory_util                     dijkstra/original.py
# 190  cold_start_memory_util                     fannkuch/original.py
# 191  cold_start_memory_util                     fannkuch/original.py
# 197  cold_start_memory_util                   mandlebrot/original.py
# 210  warm_start_memory_util                 binary_trees/original.py
# 218  warm_start_memory_util                     dijkstra/original.py
# 225  warm_start_memory_util                   mandlebrot/original.py
# 227  warm_start_memory_util                   mandlebrot/original.py
#
#     compilation  statistic   p_value  is_normal (p > 0.05)
# 3      original   0.871211  0.035152                 False
# 27     original   0.834609  0.010593                 False
# 38        numba   0.863991  0.027567                 False
# 42     original   0.861064  0.025002                 False
# 44        numba   0.875401  0.040533                 False
# 64       cython   0.854295  0.019987                 False
# 90     original   0.759572  0.001165                 False
# 91       cython   0.797526  0.003418                 False
# 92        numba   0.830511  0.009310                 False
# 93     original   0.775888  0.001833                 False
# 94       cython   0.793606  0.003047                 False
# 95        numba   0.855924  0.021088                 False
# 96     original   0.834230  0.010467                 False
# 97       cython   0.866248  0.029734                 False
# 98        numba   0.801962  0.003896                 False
# 99     original   0.852705  0.018971                 False
# 100      cython   0.524528  0.000006                 False
# 102    original   0.728268  0.000507                 False
# 103      cython   0.865003  0.028517                 False
# 104       numba   0.811965  0.005257                 False
# 106      cython   0.780974  0.002117                 False
# 108    original   0.685381  0.000174                 False
# 110       numba   0.523065  0.000005                 False
# 111    original   0.865123  0.028632                 False
# 112      cython   0.732308  0.000563                 False
# 113       numba   0.862442  0.026176                 False
# 114    original   0.614454  0.000035                 False
# 117    original   0.823682  0.007525                 False
# 119       numba   0.864470  0.028013                 False
# 123    original   0.803249  0.004048                 False
# 124      cython   0.844929  0.014732                 False
# 126    original   0.803331  0.004058                 False
# 128       numba   0.845583  0.015046                 False
# 129    original   0.827606  0.008501                 False
# 132    original   0.807840  0.004643                 False
# 133      cython   0.864641  0.028173                 False
# 134       numba   0.796649  0.003331                 False
# 138    original   0.773504  0.001714                 False
# 139      cython   0.747184  0.000834                 False
# 140       numba   0.850298  0.017535                 False
# 147    original   0.789977  0.002742                 False
# 157      cython   0.766727  0.001419                 False
# 159    original   0.856234  0.021305                 False
# 160      cython   0.781032  0.002121                 False
# 161       numba   0.865067  0.028578                 False
# 162    original   0.805174  0.004287                 False
# 164       numba   0.733679  0.000583                 False
# 166      cython   0.792051  0.002912                 False
# 170       numba   0.833044  0.010082                 False
# 172      cython   0.878326  0.044797                 False
# 178      cython   0.863045  0.026709                 False
# 180    original   0.860106  0.024218                 False
# 188       numba   0.858083  0.022647                 False
# 190      cython   0.872031  0.036143                 False
# 191       numba   0.876632  0.042274                 False
# 197       numba   0.876733  0.042420                 False
# 210    original   0.810079  0.004966                 False
# 218       numba   0.830969  0.009445                 False
# 225    original   0.808797  0.004778                 False
# 227       numba   0.832294  0.009846                 False
